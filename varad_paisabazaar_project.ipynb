# %% [markdown]
# <a href="https://colab.research.google.com/github/varad21-wg/python-/blob/main/varad_paisabazaar_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Paisabazaar Banking Fraud Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member  -** Varad Wagh

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# For this project, the goal was to analyze customer data from Paisabazaar to uncover patterns and potential red flags that might indicate banking fraud. The dataset included 100,000 records with 28 different attributes, covering key details about customers' financial habits, credit history, and loan information. Some of the important features examined were Age, SSN, Occupation, Annual Income, Credit Utilization Ratio, Payment Behavior, and Credit Score. By studying these factors, we aimed to gain deeper insights into customer behavior and identify any irregularities that could suggest fraudulent activity.
#
# **Key Aspects of the Analysis:** Data Wrangling: Since raw data often contains
# errors or inconsistencies, we began by cleaning and organizing the dataset.This included handling missing values, fixing incorrect data types, and ensuring uniformity across different columns.
#
# **Exploratory Data Analysis (EDA)**: We used various visualization techniques to understand the relationships between different features, spot trends, and get a better sense of the overall data structure.
#
# **Feature Engineering:** To enhance our analysis, we created new variables and modified existing ones to make fraud detection more effective. This helped us capture subtle patterns that might not be obvious in raw data.
#
# **Outlier Detection:** Certain behaviors—like excessively high credit utilization, large outstanding debts, or frequent delayed payments—can be signs of potential fraud. We focused on identifying these unusual patterns to flag risky profiles.
#
# **Credit Score Analysis:** We examined how credit scores varied across different occupations and customer profiles, looking for any suspicious trends. A low or abnormal credit score could be an indicator of financial instability or fraud.
#
# **Loan and Payment Behavior:** By analyzing different types of loans, the number of delayed payments, and overall payment habits, we aimed to spot inconsistencies that could point toward fraudulent activity.
#
# Through this analysis, we were able to gain a clearer picture of potential fraud risks within the dataset, which could be valuable for financial institutions looking to strengthen their fraud detection mechanisms.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/varad21-wg/python-/blob/main/varad_paisabazaar_project.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Given a dataset of 100,000 banking customers with detailed information about their financial activities, credit history, and personal profiles, how can we effectively analyze this data to detect and flag potential fraudulent behavior? The analysis should focus on identifying patterns and anomalies that deviate from typical customer behavior, which could indicate fraudulent activities such as credit card fraud, loan exploitation, or unusual financial transactions

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The objective of this project is to analyze customer financial and behavioral data to detect potential banking fraud and assess credit risk more effectively. By leveraging Exploratory Data Analysis and visualization techniques, our project aims to uncover hidden patterns, anomalies, and key factors that indicate fraudulent activity or poor credit performance.These insights will help financial institutions like paisabazaar strengthen fraud detection systems, optimize lending decisions, and improve overall customer risk profiling

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = pd.read_csv('/content/drive/MyDrive/paisabazaar.csv')

# %%
df = pd.DataFrame(dataset)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
# 3       19114.12            1824.843333                3.0  ...        Good
# 4       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset rows & columns count
df.shape
# Out:
# (100000, 28)

# %% [markdown]
# So, There are total 100000 rows and total 28 columns in the dataset

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
int(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar = 'coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# So, there are total 100000 rows and 28 columns in the dataset. Age column is stored as a float type, so we have to convert it into an integer type for better accuracy and interpretion.I also checked for duplicate records, but no duplicates were found in the dataset and also there no null values in the dataset.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Describe
df.describe(include='all')
# Out:
#                    ID    Customer_ID          Month      Name            Age  \
# count   100000.000000  100000.000000  100000.000000    100000  100000.000000
# unique            NaN            NaN            NaN     10128            NaN
# top               NaN            NaN            NaN  Jessicad            NaN
# freq              NaN            NaN            NaN        48            NaN
# mean     80631.500000   25982.666640       4.500000       NaN      33.316340
# std      43301.486619   14340.543051       2.291299       NaN      10.764812
# min       5634.000000    1006.000000       1.000000       NaN      14.000000
# 25%      43132.750000   13664.500000       2.750000       NaN      24.000000
# 50%      80631.500000   25777.000000       4.500000       NaN      33.000000
# 75%     118130.250000   38385.000000       6.250000       NaN      42.000000
# max     155629.000000   50999.000000       8.000000       NaN      56.000000
#
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# There are total 28 variables in the dataset which are capturing customer demographic, financial details, credit history, and behavioural patterns. There are also key features include Age, Occupation, Annual Income, Number of Bank Accounts, Credit Utilization Ratio, Outstanding Debt, and Payment Behavior, which help in understanding customer financial profiles. The target variable is Credit Score, categorized as Good, Standard, or Poor. which serves as a benchmark for assessing fraud risk and credit worthiness

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# ID                          100000
# Customer_ID                  12500
# Month                            8
# Name                         10128
# Age                             43
# SSN                          12500
# Occupation                      15
# Annual_Income                12488
# Monthly_Inhand_Salary        13241
# Num_Bank_Accounts               12
# Num_Credit_Card                 12
# Interest_Rate                   34
# Num_of_Loan                     10
# Type_of_Loan                  6261
# Delay_from_due_date             63
# Num_of_Delayed_Payment          26
# Changed_Credit_Limit          3452
# Num_Credit_Inquiries            18
# Credit_Mix                       3
# Outstanding_Debt             12203
# Credit_Utilization_Ratio    100000
# Credit_History_Age             404
# Payment_of_Min_Amount            3
# Total_EMI_per_month          11890
# Amount_invested_monthly      12261
# Payment_Behaviour                6
# Monthly_Balance              98494
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
  # Write your code to make your dataset analysis ready.
  # Ensure df is a fresh copy of the original dataset to prevent issues from prior modifications.
  df = dataset.copy()

  # Converting age column from float to integer
  df['Age'] = df['Age'].astype(int)

  #checking for duplicate values
  duplicates = df.duplicated().sum()
  print("Number of duplicate row:", duplicates)

  #checking for null values
  null_values = df.isnull().sum().sum()
  print("Number of null values:", null_values)

  # verifying after cleaningw
  print("Shape after droping the duplicates and the null values:",df.shape)
# Out:
# Number of duplicate row: 0
# Number of null values: 0
# Shape after droping the duplicates and the null values: (100000, 28)

# %% [markdown]
# ## after checking the duplicates and null values. we will remove the outliers

# %%
# removing the outliers in the 'Annual_Income' column
Q1 = df['Annual_Income'].quantile(0.25)
Q3 = df['Annual_Income'].quantile(0.75)
IQR = Q3 - Q1
df = df[(df['Annual_Income'] >= (Q1 - 1.5 * IQR)) & (df['Annual_Income'] <= (Q3 + 1.5 * IQR))]

# %%
# Example: Creating a new feature 'Income_per_Account'
df['Income_per_Account'] = df['Annual_Income'] / df['Num_Bank_Accounts']
556
# Example: Creating a feature 'Credit_Score_Level'
df['Credit_Score_Level'] = df['Credit_Score'].apply(lambda x: 'High' if isinstance(x, int) and x > 700 else 'Low')

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# as per my exploration the 'Age' column was stored as float data type, so we converted it to integer for better accuracy.Then we searched for any duplicate and null values within the dataset but no duplicates or any null values were found. After that we calculated removed the outliers in 'Annual_Income' using IQR method.we then Converted 'credit_score' to numeric and also removed the nan values in 'credit_score' for better accuracy. Also, we have created two new feature 'Income_per_account' and 'Credit_score_level' in the dataset for furture more understading of the customer

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 Numbers of customers by occupation - Bar chart(Demographic analysis)

# %%
Occupation_wise_no_of_customers = df['Occupation'].value_counts().reset_index()
Occupation_wise_no_of_customers
# Out:
#        Occupation  count
# 0          Lawyer   6960
# 1        Engineer   6720
# 2       Architect   6672
# 3        Mechanic   6648
# 4       Scientist   6624
# 5   Media_Manager   6600
# 6       Developer   6592
# 7      Accountant   6576
# 8         Teacher   6544
# 9    Entrepreneur   6496
# 10         Doctor   6456
# 11     Journalist   6392
# 12        Manager   6288
# 13       Musician   6216
# 14         Writer   6216

# %%
# Create the bar plot
plt.figure(figsize=(12,6))
sns.barplot(x = 'Occupation', y = 'count', data = Occupation_wise_no_of_customers, palette='viridis')
plt.title('Occupation-wise number of customers')
plt.xlabel('Occupation')
plt.ylabel('No. of customers')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar plot is best suited for categorical data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It shows that certain occupation like lawyers and engineers dominate the data

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# It helps the Identify the high value customers to target for loans and credit products

# %% [markdown]
# #### Chart - 2 Distribution of Age - Histogram

# %%
# Chart - 2 visualization code
sns.histplot(df['Age'], color='teal')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histgram is best reveal distribution trends across a continous variable

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most customers are concentrated in the working age bracket(25-40 years)

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These allows Paisabazaar to trailor financial products for most active age group

# %% [markdown]
# #### Chart - 3 Annual_Income by Occupation - Box plot

# %%
# Groupby  Occupation and Annual_Income column
Occupation_wise_Income = df.groupby('Occupation')['Annual_Income'].sum().reset_index()
Occupation_wise_Income
# Out:
#        Occupation  Annual_Income
# 0      Accountant   3.141720e+08
# 1       Architect   3.283849e+08
# 2       Developer   3.154482e+08
# 3          Doctor   3.062747e+08
# 4        Engineer   3.245303e+08
# 5    Entrepreneur   3.138129e+08
# 6      Journalist   2.927894e+08
# 7          Lawyer   3.293012e+08
# 8         Manager   3.075157e+08
# 9        Mechanic   3.183117e+08
# 10  Media_Manager   3.200553e+08
# 11       Musician   3.037369e+08
# 12      Scientist   3.251911e+08
# 13        Teacher   3.115764e+08
# 14         Writer   3.072092e+08

# %%
# Chart - 3 visualization code
plt.figure(figsize=(12,8))
sns.boxplot(x = 'Occupation', y = 'Annual_Income', data = df)
plt.xticks(rotation = 45)
plt.title('Occupation wise Income')
plt.xlabel('Occupation')
plt.ylabel('Annual Income')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It is easy income spread and also outliers through boxplot

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# These shows that salaried individuals earns higher and more stable Income

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It informs creditworthness by linking annual income to occupation

# %% [markdown]
# #### Chart - 4  Annual Income distribution - Histogram

# %%
# Chart - 4 visualization code
sns.histplot(df['Annual_Income'])
plt.title('Distribution of Annual Income')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Useful for visualizing skeness and spread in customer income levels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Income distribution is slightly skewed, with many customers in lower-to-mid income ranges

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It helps to identify affordability ranges and potential loan size limits.

# %% [markdown]
# #### Chart - 5 Monthly In-Hand Salary Vs Credit Score - Boxplot(Income & Salary Insights)

# %%
# Chart - 5 visualization code
plt.figure(figsize=(10, 6))
sns.boxplot(x = 'Credit_Score', y = 'Monthly_Inhand_Salary', data = df)
plt.title('Montly In-Hand Salary Vs Credit Score')
plt.xlabel('Credit Score')
plt.ylabel('Montly In-Hand Salary')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# shows salary variation relates to credit score categories

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Customers with higher salary are more often in Good credit score group.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# It demonstrates salary as a predictor of repayment ability and creditworthness.

# %% [markdown]
# #### Chart - 6 Comparing Income distribution of Good Vs poor Credit Score Customers - KDE plot(Income & Salary Insights)

# %%
# Chart - 6 visualization code
plt.figure(figsize = (10, 6))

# KDE plot for Good Credit Score Customers
sns.kdeplot(df[df['Credit_Score'] == 'Good']['Annual_Income'], label = 'Good Credit Score', shade=True)

# KDE plot for poor Credit Score Customers
sns.kdeplot(df[df['Credit_Score'] == 'Poor']['Annual_Income'], label = 'Poor Credit Score', shade=True, color='red')

plt.title('Income distribution of Good Vs poor Credit Score Customers')
plt.xlabel('Annual Income')
plt.ylabel('Density')
plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# KDE highlights income density between groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here good credit scoreres clusters around higher income levels, while poor scorers are more spread in lower range

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Reinforces that income strongly influnces repayment and credit risk.

# %% [markdown]
# #### Chart - 7  Average number of loans Vs credit Score - Barplot

# %%
# Chart - 7 visualization code
plt.figure(figsize=(10,6))
sns.barplot(x = 'Credit_Score', y = 'Num_of_Loan', data = df, palette='viridis')
plt.title('Average number of loans Vs credit Score')
plt.xlabel('Credit Score')
plt.ylabel('Number of Loan')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Simple comparison of average across categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# These shows that poor credit scorers holds more number of loans as compared to good credit scorers

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Multiple acitve loans increases default risk these can guide stricter multi-loan approval checks.

# %%
df.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score', 'Income_per_Account', 'Credit_Score_Level'],
#       dtype='object')

# %% [markdown]
# #### Chart - 8 Types of loans availed by customers - Stacked barchart

# %%
  # Spliting the Type of loan column
  loan_split = df['Type_of_Loan'].str.get_dummies(sep = ',')

  # Adding Credit_Score to the loan_split DataFrame to analyze loans by score group
  loan_by_score = pd.concat([df['Credit_Score'], loan_split], axis=1)

  # Group by Credit Score and sum
  loan_distribution = loan_by_score.groupby('Credit_Score').sum()

  #plot the stacked bar plot
  loan_distribution.plot(kind = 'bar', stacked = True, figsize = (10,6))
  plt.title('Types of loans availed by customers')
  plt.xlabel('Credit score category')
  plt.ylabel('Number of loans')
  plt.legend(title ='loan types', bbox_to_anchor =(1.05, 1), loc = 'upper left')
  plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Stacked barchart is really effective to show how loan types are distributed across customers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It shows that personal loan, credit card dominate, with customer holding multiple loans shows weaker Credit Score.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Helps lenders identify over-leverged customers and control loan approvals accordingly.

# %% [markdown]
# #### Chart - 9   Outstanding Debt Vs Annual Income(with Credit Score as color) - Scatter plot

# %%
# Chart - 9 visualization code
plt.figure(figsize = (10, 6))
sns.scatterplot(x = 'Annual_Income', y = 'Outstanding_Debt', hue = 'Credit_Score', data = df)
plt.title('Outstanding Debt Vs Annual Income(with Credit Score as color)')
plt.xlabel('Annual Income')
plt.ylabel('Outstanding Debt')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter plot is the option to show relation between Income and Debt with Credit Score

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that poor scorers has higher Debt at low income and good scorers has lower debt and better balance.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Identify risky low income/high debt customers. Refine loan approvals using debt-to-income ratio.and then target stable customers for premium products.

# %% [markdown]
# #### Chart - 10 Number of Delayed Vs Credit Score - Box plot

# %%
# Chart - 10 visualization code
plt.figure(figsize=(10, 6))
sns.boxplot(x = 'Credit_Score', y = 'Num_of_Delayed_Payment', data = df)
plt.title('umber of Delayed Vs Credit Score')
plt.xlabel('Credit Score')
plt.ylabel('Number of Delayed Payments')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Boxplots capture repayment irregularities per credit score group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Poor scores have a much higher number of delayed payments.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Strong evidence that repayment discipline directly impacts Credit ratings.

# %% [markdown]
# #### Chart - 11 Delay from Due date distribution - Histogram & KDE plot.

# %%
# Chart - 11 visualization code
plt.figure(figsize = (10,6))
sns.histplot(df['Delay_from_due_date'], bins = 30, edgecolor = 'black', kde = True )
plt.title('Delay from Due date distribution ')
plt.xlabel('Delayed date')
plt.ylabel('Number of customers')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Histograms and KDE plots show the frequency and distribution of delays, helping visualize repayment behavior.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Many customers have consistent payment delays, which correlates with poor credit scores.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Enables the company to track repayment discipline and set up automated reminders or stricter monitoring for chronic defaulters.

# %% [markdown]
# #### Chart - 12 Credit Utilization Ratio Grouped By Credit Score - Bar chart

# %%
# Chart - 12 visualization code
plt.figure(figsize = (10, 6))
sns.barplot(x = 'Credit_Utilization_Ratio', y = 'Credit_Score', data = df)
plt.title('Credit Utilization Ratio Grouped By Credit Score')
plt.xlabel('Credit utilization')
plt.ylabel('Credit score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# These chart clearly shows how utilization varies by group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Poor scorers have the highest utilization ratio, while good scorers keep it low.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Can be used as an early warning KPI to flag risky customers.

# %% [markdown]
# #### Chart - 13 Payment Behaviour Distribution - Donut Chart

# %%
payment_behaviour_counts = df['Payment_Behaviour'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(payment_behaviour_counts, labels = payment_behaviour_counts.index, autopct = '%1.1f%%', startangle = 90)
plt.title('Payment Behaviour Distribution')
plt.legend(title = 'Payment Behaviour', bbox_to_anchor = (1.05, 1), loc = 'upper left')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts are effective for proportional breakdowns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The dataset shows a sizable share of customers with delayed or partial payments.

# %% [markdown]
# #### Chart - 14 Correlation Between Numerical Features - Heatmap

# %%
# select numerical features only
num_df = df.select_dtypes(include = ['int64','float64'])

# Compute correclation matrix
corr = num_df.corr()

# plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot = True, fmt = ".2f", cmap="coolwarm", cbar = True)
plt.title('Correlation Between Numerical Features')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Heatmaps are ideal for showing correlations between multiple numerical features.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Strong positive correlation between Annual Income & Montly Salary, and between Debt & EMI. Credit Utilization Ratio is strongly tied to credit score.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Helps in feature selection for predictive models, reducing redundancy and improving accuracy in fraud detection.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Chart - 6 visualization code
# Subset the relevant columns and filter the dataset to remove invalid or unknown values in Credit_Score
df_filtered = df[df['Credit_Score'].isin(['Good', 'Standard', 'Poor'])]

# Select columns of interest for the pairplot
cols_of_interest = ['Age', 'Annual_Income', 'Monthly_Balance', 'Outstanding_Debt', 'Credit_Score']

# Create a pairplot with hue based on Credit Score
sns.pairplot(df_filtered[cols_of_interest], hue='Credit_Score', palette='coolwarm')
plt.suptitle('Pairplot of Age, Income, Balance, and Debt Colored by Credit Score', y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# A pairplot is chosen to visualize pairwise relationships and distributions among all selected numerical features, providing a comprehensive overview of how each feature interacts with others, colored by Credit Score for further insights into creditworthiness. Due to the large number of features, this plot can be computationally intensive and may take some time to generate.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# After executing the code, we will analyze the pairplot to identify patterns such as:
# *   **Correlation:** Observe which pairs of features show a strong positive or negative correlation, indicated by the spread of data points.
# *   **Distribution:** Examine the univariate distributions on the diagonal to understand the spread and skewness of individual features.
# *   **Credit Score Separation:** Look for clusters or clear separations of 'Good', 'Standard', and 'Poor' credit scores across different feature pairs. For instance, if 'Poor' credit scores consistently appear in regions of high debt or low income.
# *   **Outliers:** Identify any data points that stand out, which could represent unusual customer behavior or potential fraud indicators.
#
# Once the chart is generated, I can provide more specific insights based on the visual patterns.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
#
# Yes, the insights gained from the pairplot will be highly beneficial for creating a positive business impact:
# *   **Enhanced Fraud Detection:** By understanding the relationships between various financial and behavioral features and credit scores, we can develop more robust fraud detection models. Anomalous relationships, especially among 'Poor' credit score holders, can be flagged for further investigation.
# *   **Improved Credit Risk Assessment:** The plot can reveal which combinations of features are most indicative of credit risk, allowing Paisabazaar to refine its lending criteria and credit scoring models. This can lead to more accurate assessments of applicants' ability to repay loans.
# *   **Targeted Product Development:** Identifying distinct patterns for different credit score groups can help in tailoring financial products. For example, customers with 'Good' credit scores and specific financial behaviors might be targeted with premium products, while those with 'Standard' scores might receive offers designed to improve their credit health.
# *   **Early Warning Systems:** Continuous monitoring of these relationships can help establish early warning systems for customers whose financial behavior starts to deviate towards patterns associated with lower credit scores, enabling proactive intervention.
#
# Negative growth insights could arise if the pairplot reveals that certain features, previously considered positive indicators, are actually correlated with higher risk or poor credit outcomes. For example, if a high number of certain types of loans, even with seemingly good income, consistently leads to 'Poor' credit scores, it would suggest a need to reassess loan approval policies for such combinations. Such insights would necessitate adjustments in business strategy to mitigate potential risks.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To address the business objective of reducing fraud risk and improving credit portfolio quality, I recommend a data driven approach using the insights derived from the analysis. First, customers can be segmented based on their credit score, debt levels, and utilization should be flagged for closer monitoring. The institution should encourage timely payments by offering reminders, flexible repayment plans, and financial counseling. At the same time predictive models can be developed to identify early warning signals of potential fraud or default. By promoting responsible borrowing and proactive engagement, the bank can improve repayment rates. Automated alerts and stricter loan eligibility criteria for high-risk customers will further reduce exposure. Meanwhile, low-risk customers should be rewarded with better credit terms to strengthen loyalty. Over time, these actions will not only reduce fraud but also improve the overall profitability and customer trust of the organization.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# After analyzing the data, several insights emerged that could help in detecting fraud:
#
# Occupation and Credit Score Patterns: Some occupations showed unusual distributions of credit scores. This could indicate potential fraudulent activities, particularly if certain professions are overrepresented in low-credit-score categories.
#
# Credit Utilization Ratio: Customers with extremely high credit utilization were flagged as potential risks. High credit utilization can indicate financial distress, a key indicator of possible fraud.
#
# Payment Behavior: Customers with a history of missed payments or delays in settling debts were found to have lower credit scores and higher outstanding debts. These behavioral patterns could be used to monitor and predict fraud.
#
# Loan Details: The analysis of loan types and the number of loans revealed that some customers have excessive loan numbers, which could be a sign of fraudulent attempts to exploit the banking system.
#
# Final Thoughts: The project successfully identified key areas of risk and potential fraud indicators within the customer base. By combining data wrangling, exploratory data analysis, and advanced visualizations, we were able to highlight patterns that can be further investigated to develop fraud detection systems. Moving forward, machine learning algorithms can be employed to automate and improve the accuracy of fraud detection based on the features identified in this analysis.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
